# %%
from sympy import * 
from IPython.display import Image

# %% [markdown]
# __1.__ Найти предел последовательности:

# %% [markdown]
# ### $$а)\,\,\,\,\lim_{n\to \infty} \frac{(23-2n^2)(3n^2+17)^2}{4n^6+n-1}=\Bigl(\frac{\infty}{\infty}\Bigr)=\frac{(-2)\cdot3^2}{4+1}=-\frac{18}{5}$$

# %% [markdown]
# ### $$б)\,\,\,\,\lim_{n\to \infty} \frac{(97-2n)^3}{2n(3n^2+15)+8n}=\Bigl(\frac{\infty}{\infty}\Bigr)=\frac{(-2)^3}{6+8}=-\frac{4}{7}$$

# %% [markdown]
# ### $$в)\,\,\,\,\lim_{n\to \infty} \frac{2n^3+13n(n+18)}{(27-n)(2n+19)^2}=\Bigl(\frac{\infty}{\infty}\Bigr)=\frac{2+13}{-1\cdot(2)^2}=-\frac{15}{4}$$

# %% [markdown]
# ### $$г)\,\,\,\,\lim_{n\to \infty} (\sqrt{n^2+1}-n)=(\infty-\infty)=$$
#
# ### $$=\lim_{n\to \infty} (\sqrt{n^2+1}-{n})\cdot\frac{\sqrt{n^2+1}+{n}}{\sqrt{n^2+1}+{n}}=$$
#
# ### $$=\lim_{n\to \infty} \frac{n^2+1-n^2}{\sqrt{n^2+1}+{n}}=$$
#
# ### $$=\lim_{n\to \infty} \frac{1}{\sqrt{n^2+1}+{n}}=\Bigl(\frac{1}{\infty}\Bigr)=0$$

# %% [markdown]
# ### $$д)\,\,\,\,\lim_{n\to \infty} \frac{(-4)^n+5\cdot7^n}{(-4)^{n-1}+7^{n+2}}=\Bigl(\frac{\infty}{\infty}\Bigr)=\frac{5}{49}$$

# %% [markdown]
# ### $$e)^*\,\,\,\,\lim_{n\to \infty} \Bigl(\frac{1}{1\cdot2}+\frac{1}{2\cdot3}+\frac{1}{3\cdot4}+...+\frac{1}{(n-1)\cdot n}\Bigr)$$

# %% [markdown]
# __2.__ Представьте $1$ в виде суммы трех рациональных дробей с разными знаменателями и числителем равным $1$.

# %%
for a in range(2, 100):
    for b in range(a, 100):
        for c in range(b, 100):
            if a*b*c == b*c + a*c + a*b and a != b != c != a:
                print(a, b, c)
                print('Сумма дробей =', 1/a + 1/b + 1/c )
# Out:
# 2 3 6
# Сумма дробей = 0.9999999999999999

# %% [markdown]
# __3$^*$.__ Тоже задание, только в виде суммы шести дробей.

# %%
for a in range(2, 100):
    for b in range(a, 100):
        for c in range(b, 100):
            for d in range(c, 100):
                for e in range(d, 100):
                    for f in range(e, 100):
                        if a*b*c*d*e*f == a*b+a*c+a*d+a*e+a*f+b*c+b*d+b*e+b*f+c*d+c*e+c*f+d*e+d*f+e*f and a != b != c !=d !=e !=f:
                            print(a, b, c, d, e, f)
                            print('Сумма дробей =', 1/a + 1/b + 1/c + 1/d + 1/e + 1/f)

# %% [markdown]
# __4.__ Пользуясь критерием Коши, докажите сходимость последовательности:
#
# ### $$a_n=\frac{\sin1}{2}+\frac{\sin2}{2^2}+\frac{\sin3}{2^3}+..\frac{\sin n}{2^n}\,\,\,\,\,\Rightarrow$$
#
# ### $$\Bigl\{a_n\Bigr\}_{n=1}^\infty=\Bigl\{\frac{\sin1}{2}, \frac{\sin1}{2}+\frac{\sin2}{2^2}, ..., a_n,...\Bigr\}$$

# %%
display(Image(filename='20200808_180340.jpg', width = 1000))
